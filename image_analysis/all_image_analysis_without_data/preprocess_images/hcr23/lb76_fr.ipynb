# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pylab as plt
import os
import ipywidgets as widgets

import pyclesperanto_prototype as cle
from scipy import ndimage
from skimage.morphology import binary_closing, binary_opening, disk
from aicsimageio import AICSImage
from apoc import ObjectSegmenter
import napari

# %%
from image_analysis.read_files import get_paths, change_paths
from image_analysis.preprocess import plot
from image_analysis.preprocess import mask
from image_analysis.fit import roi

# %% [markdown]
# # Preproccesing

# %%
from inputs import *

# %% [markdown]
# ### <span style='color:Red'> [Manual input]  </span>  Image folder

# %%
image_folder = r'/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/'

# %%
img_paths = get_paths(image_folder, exclude='.lif_', suffix='.lif')
img_paths = change_paths(img_paths, '', 'lifext')
img_paths = change_paths(img_paths, '', 'bleached')
img_paths = change_paths(img_paths, '', 'tif')
img_paths = change_paths(img_paths, '', 'ctr')
img_paths = change_paths(img_paths, '', '15cm')
img_paths = change_paths(img_paths, '', 'd1d2d3')

# %%
i = 0
for path in img_paths:
    print(i, path)
    i += 1
# Out:
# 0 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/hcr23_20241001_lb77_fl_t2#9.lif
# 1 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/hcr23_20240927_lb79_fl_t4a#1.lif
# 2 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/hcr23_20240927_lb80_fl_t4a#2_dd.lif
# 3 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/hcr23_20240927_lb76_fl_t1#4.lif
# 4 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/hcr23_20240927_lb76_fr_t1#4.lif
# 5 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/hcr23_20240927_lb79_fr_t4a#1.lif
# 6 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/hcr23_202410015_lb78_fl_t3#14.lif
# 7 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/hcr23_202410015_lb78_fr_t3#14.lif
# 8 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/hcr23_20240927_lb80_fr_t4a#2_dd.lif
# 9 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/hcr23_20241001_lb77_fr_t2#9.lif
# 10 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241001_5cm_an14067_8d_t1#7/hcr23_20241001_5cm_an14067_8d_fl_d3d4_t1#7.lif
# 11 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241001_5cm_an14067_8d_t1#7/hcr23_20241001_5cm_an14067_8d_fr_t1#7.lif
# 12 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241005_5cm_an14071_10d_t2#12/hcr23_20241005_5cm_an14071_fl_10d_fl_t2#12.lif
# 13 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241011_5cm_an14072_7d_t3#16/hcr23_20241011_5cm_an14072_7d_fl_t3#16.lif
# 14 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241011_5cm_an14072_7d_t3#16/hcr23_20241014_5cm_an14074_10d_fl_t2#13_reimaged.lif
# 15 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241002_5cm_an14073_8d_t1#8/hcr23_20241002_5cm_an14073_8d_fl_t1#8.lif
# 16 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20240927_5cm_an14064_5d_t1#5/hcr23_20240927_5cm_an14064_5d_fr_t1#5.lif
# 17 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20240927_5cm_an14064_5d_t1#5/hcr23_20240927_5cm_an14064_5d_fl_d2d3_t1#5.lif
# 18 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241011_5cm_an14063_7d_t3#15/hcr23_20241011_5cm_an14063_7d_fl_d2d3_t3#15_all.lif
# 19 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241004_5cm_an14070_6d_t2#11/hcr23_20241004_5cm_an14070_6d_fl_t2#11.lif
# 20 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241004_5cm_an14070_6d_t2#11/hcr23_20241004_5cm_an14070_6d_fl_t2#11_repeat.lif
# 21 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241004_5cm_an14066_6d_t2#10/hcr23_20241004_5cm_an14066_6d_fr_t2#10.lif
# 22 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241004_5cm_an14066_6d_t2#10/hcr23_20241004_5cm_an14066_6d_fl_d2d3_t2#10.lif
# 23 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20240927_5cm_an14065_16d_t3#3/hcr23_20240927_5cm_an14065_16d_fl_t3#3.lif
# 24 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241011_5cm_an14065_16d_fr_t3317/hcr23_20241011_5cm_an14065_16d_fr_t3#17.lif
# 25 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241002_5cm_an14068_5d_t1#6/hcr23_20241002_5cm_an14068_5d_fr_t1#6.lif
# 26 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dusp_gfp/hcr23_20241002_5cm_an14068_5d_t1#6/hcr23_20241002_5cm_an14068_5d_fl_d3d4_t1#6.lif
# 27 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dd_edu/hcr23_20241015_5cm_an13187_7d_t4b324_dd_edu.lif
# 28 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dd_edu/hcr23_20241016_5cm_an13188_11d_t4b#25_dd_edu.lif
# 29 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dd_edu/hcr23_20241015_5cm_an13195_9d_t4b324_dd_edu.lif
# 30 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dd_edu/hcr23_20241015_5cm_an13203_5d_t4b324_dd_edu.lif
# 31 /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/5cm_dd_edu/hcr23_20241016_5cm_an13211_13d_t4b#25_dd_edu.lif

# %% [markdown]
# ### <span style='color:Red'> [Manual input]  </span>  choose file

# %%
i = 4
img_path = img_paths[i]
print(img_path)
# Out:
# /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/hcr23_20240927_lb76_fr_t1#4.lif

# %%
image_folder_tif = os.path.join(
    os.path.dirname(img_path), 
    'tif'
)

# %%
sample = os.path.basename(img_path).split('.')[0]
sample = sample.split('_')[2] + '_' + sample.split('_')[3]
sample
# Out:
# 'lb76_fr'

# %%
img_paths = get_paths(image_folder_tif, suffix='tif')
img_paths = change_paths(img_paths, include=sample)
img_paths
# Out:
# ['/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c6_hcr23_20240927_lb76_fr_t1#4.tif',
#  '/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c1_hcr23_20240927_lb76_fr_t1#4.tif',
#  '/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c5_hcr23_20240927_lb76_fr_t1#4.tif',
#  '/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c2_hcr23_20240927_lb76_fr_t1#4.tif',
#  '/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c4_hcr23_20240927_lb76_fr_t1#4.tif',
#  '/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c3_hcr23_20240927_lb76_fr_t1#4.tif']

# %%
img_paths = sorted(
    img_paths,
    key = lambda c: c.split('tif/c')[1].split('_')[0]
)

# %%
img_paths
# Out:
# ['/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c1_hcr23_20240927_lb76_fr_t1#4.tif',
#  '/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c2_hcr23_20240927_lb76_fr_t1#4.tif',
#  '/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c3_hcr23_20240927_lb76_fr_t1#4.tif',
#  '/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c4_hcr23_20240927_lb76_fr_t1#4.tif',
#  '/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c5_hcr23_20240927_lb76_fr_t1#4.tif',
#  '/home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c6_hcr23_20240927_lb76_fr_t1#4.tif']

# %% [markdown]
# ### Load images

# %%
#  0.5411x0.5411x3.9991

pixel_size_x, pixel_size_y, pixel_size_z = 0.5411, 0.5411, 3.9991

print('physical pixels sizes x, y, z:   ', pixel_size_x, pixel_size_y, pixel_size_z)

pixel_size_z = downsample * pixel_size_z * 1e-6
pixel_size_y = downsample * pixel_size_y * 1e-6
pixel_size_x = downsample * pixel_size_x * 1e-6

pixel_size = np.array([pixel_size_z, -pixel_size_y, pixel_size_x]) # (ez, ey, ex) corresponds k, i, j table indexes

print('downsamples pixels sizes x, y, z:', pixel_size_x, pixel_size_y, pixel_size_z)
# Out:
# physical pixels sizes x, y, z:    0.5411 0.5411 3.9991
# downsamples pixels sizes x, y, z: 1.0822e-06 1.0822e-06 7.998199999999999e-06

# %%
import tifffile

# %%
img = []
for path in img_paths:
    print(path)
    i = tifffile.imread(path)
    #print(i.shape)
    img.append(i[::downsample, ::downsample, ::downsample])
img = np.array(img).astype( np.uint16 )
# Out:
# /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c1_hcr23_20240927_lb76_fr_t1#4.tif
# /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c2_hcr23_20240927_lb76_fr_t1#4.tif
# /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c3_hcr23_20240927_lb76_fr_t1#4.tif
# /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c4_hcr23_20240927_lb76_fr_t1#4.tif
# /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c5_hcr23_20240927_lb76_fr_t1#4.tif
# /home/natalia/Documents/github_image_analysis/experimental_data/hcr23/lb/tif/c6_hcr23_20240927_lb76_fr_t1#4.tif

# %%
img.shape
# Out:
# (6, 20, 512, 512)

# %%
from inputs import channels

# %%
channels = list(channels.keys())

# %%
channels
# Out:
# ['fgf', 'shh', 'bright', 'dapi', 'dusp', 'edu']

# %%
img = dict(zip(channels, img))

# %% [raw]
# viewer = napari.Viewer()
# for key in img.keys():
#     viewer.add_image( img[key], name = key )

# %%
del img['edu']
del img['dapi']
del img['bright']

# %% [markdown]
# ### Isotropic

# %%
print('make isotropic')

pixel_size_aim = pixel_size_aim_user_def

scaling_x= pixel_size_x/pixel_size_aim
scaling_y= pixel_size_y/pixel_size_aim
scaling_z= pixel_size_z/pixel_size_aim

print('original pixel sizes x y z', pixel_size_x, pixel_size_y, pixel_size_z )
print('scaling facttors x y z', scaling_x, scaling_y, scaling_z)
# Out:
# make isotropic
# original pixel sizes x y z 1.0822e-06 1.0822e-06 7.998199999999999e-06
# scaling facttors x y z 0.5411 0.5411 3.9991

# %%
for key in img:
    img[key] = cle.scale(img[key], None, scaling_x, scaling_y, scaling_z, centered=False, auto_size=True, linear_interpolation=True)
    img[key] = (np.array(img[key])).astype( np.uint16 )

pixel_size = np.array([pixel_size_aim, -pixel_size_aim, pixel_size_aim])

# %%
plot.preview(img, 0.5, 1, False, 'none')

# %% [markdown]
# # (Rotate) and Crop tissue

# %% [raw]
# viewer = napari.Viewer()
# for key in img.keys():
#     viewer.add_image( img[key][:, :180, :], name = key )

# %%
for key in img.keys():
    img[key] = img[key][:, :180, :]

# %% [markdown]
# ## Tissue mask

# %% [markdown]
# ### <span style='color:Red'> [Manual input]  </span>  Tissue mask name

# %%
# make mask name
print('tissue mask name:')
mask_segmeter_path = 'tissue_mask_' + sample + '.cl'
#mask_segmeter_path = 'tissue_mask_5cm_9dpa_hoechst.cl'
print(mask_segmeter_path)
# Out:
# tissue mask name:
# tissue_mask_lb76_fr.cl

# %% [markdown]
# ### <span style='color:Red'> [Manual input]  </span> segment tissue
# ### brown - outside; blue - line along inside border, brush size - 10 for both

# %% [raw]
# # View image to make supervised segmentation
# viewer = napari.Viewer()
# viewer.add_image( img['fgf'] )

# %% [raw]
# # python code to apply this object segmenter
# segmenter = ObjectSegmenter(opencl_filename=mask_segmeter_path)
# result = segmenter.predict( image = img['fgf'] )
# segmentation_lpcm = cle.label_pixel_count_map(result)
# #keep only the largest object
# img['tissue_mask'] = (np.where(segmentation_lpcm ==  np.max(segmentation_lpcm), 1, 0)).astype( np.uint16 )

# %%
img['tissue_mask'] = tifffile.imread('tissue_mask_lb76_fr.tif')
img['tissue_mask'] = mask.largest_component(img['tissue_mask'])
img['tissue_mask'] = img['tissue_mask'][:, :180, :]

# %%
@widgets.interact(z_position = (0, 0.9, 0.1))

def preview_images_z(z_position=0.5):
    z = int(z_position * img['tissue_mask'].shape[0])
    plt.imshow( img['tissue_mask'][ z, :, :], cmap='binary')
# Out:
# interactive(children=(FloatSlider(value=0.5, description='z_position', max=0.9), Output()), _dom_classes=('wid…

# %%
img['tissue_mask'][:, -1, :] = 1
img['tissue_mask'][:, :, -1] = 1

# %%
img['tissue_mask'] = mask.morph_change(img['tissue_mask'], 3, True)

# %%
img['tissue_mask'][:, 150:, 220:] = 0

# %% [raw]
# # View image to make supervised segmentation
# viewer = napari.Viewer()
# viewer.add_image(  img['dusp'],        name='dusp' )
# viewer.add_labels( img['tissue_mask'], name='tissue_mask' )

# %%
#img['tissue_mask'] = viewer.layers['tissue_mask'].data
img['tissue_mask'] = mask.largest_component( img['tissue_mask'] )

# %% [markdown]
# # Epidermis mask

# %% [raw]
# # View image to make supervised segmentation
# viewer = napari.Viewer()
# viewer.add_image( img['dusp'] )
# viewer.add_image( img['tissue_mask'] )

# %%
img['epidermis_mask'] = mask.epiderm(img['tissue_mask'], 12, extend_along_x=True, extend_along_y=True, extend_along_z=True)

# %%
img['epidermis_mask'] = mask.largest_component( img['epidermis_mask'] )

# %% [raw]
# # View image to make supervised segmentation
# viewer = napari.Viewer()
# viewer.add_image( img['dusp'] )
# viewer.add_image( img['epidermis_mask'] )

# %% [markdown]
# # Crop only tissue

# %%
img = mask.crop(img, img['epidermis_mask'])
# Out:
# Dictionary with 3D data

# %% [markdown]
# ## Substruct background

# %%
import copy
img['tissue_mask_with_epi'] = copy.deepcopy(img['tissue_mask'])
img['tissue_mask']          = img['tissue_mask'] * mask.invert(img['epidermis_mask'])# * mask.invert(img['artifacts_mask'])

# %%
for key in img.keys():
    if key.find('mask') < 0:
        img[key] = mask.subtract_bg_clip(img[key], img['tissue_mask'], img['tissue_mask_with_epi'])
# Out:
# Masks for clipping and background subtraction are different.
# Mean background value = 598.301441077063
# Masks for clipping and background subtraction are different.
# Mean background value = 536.8354404955928
# Masks for clipping and background subtraction are different.
# Mean background value = 747.9405050135656

# %%
plot.preview(img, 0.5, 1, False, 'none')

# %% [raw]
# # View image to make supervised segmentation
# viewer = napari.Viewer()
# for key in img.keys():
#     viewer.add_image( img[key], name=key )

# %% [markdown]
# ## Segment Shh

# %%
ch_name = 'shh'

# %% [raw]
# # View image to make supervised segmentation
# viewer = napari.Viewer()
# viewer.add_image( img[ch_name][:, :, :] )

# %%
from scipy.ndimage import gaussian_filter

# %%
for_mean = copy.deepcopy( img[ch_name] )
for_mean = for_mean.astype(float)
for_mean[for_mean == 0] = np.nan
norm_along_z = gaussian_filter( np.nanmean( np.nanmean( for_mean[:, 80:90, 120:130], 1), 1), 5, mode='reflect')
norm_along_z = norm_along_z/np.nanmax(norm_along_z)
norm_along_z_broadcasted = norm_along_z[:, np.newaxis, np.newaxis]

# %%
plt.plot( norm_along_z )

# %%
shh_norm = copy.deepcopy( img[ch_name] )
N0 = 1#norm_along_z[np.where(np.isnan(norm_along_z))[0][0]-1]
shh_norm = np.where(np.isnan(norm_along_z_broadcasted), shh_norm/N0, shh_norm / norm_along_z_broadcasted)

# %% [raw]
# # View image to make supervised segmentation
# viewer = napari.Viewer()
# viewer.add_image( shh_norm[:, :, :] )

# %%
image_filtered = np.zeros_like( shh_norm )
image_filtered[:, :, :] = mask.gfilter( shh_norm[:, :, :], sigma )
image_filtered = mask.minmaxnorm( image_filtered )
# Out:
# Relative dynamic range, (max - min)/max = 0.8407689666783776

# %%
for pc in [40, 60, 70, 80]:
    img[ch_name + str(pc) + '_clip'] = img[ch_name] * (image_filtered > pc * 0.01).astype(np.uint16)

# %%
img[ch_name+'50_mask'] = (image_filtered > 0.5).astype(np.uint16)
img[ch_name+'50_clip'] = img[ch_name] * img[ch_name+'50_mask']

# %% [raw]
# # View image to make supervised segmentation
# viewer = napari.Viewer()
# for key in img.keys():
#     viewer.add_image( img[key], name=key )

# %% [markdown]
# ## Segment Fgf8

# %%
ch_name = 'fgf'

# %%
image_filtered = mask.gfilter( img[ch_name], sigma )
image_filtered = mask.minmaxnorm( image_filtered )
# Out:
# Relative dynamic range, (max - min)/max = 0.9344496414538787

# %%
for pc in [40, 60, 70, 80]:
    img[ch_name + str(pc) + '_clip'] = img[ch_name] * (image_filtered > pc * 0.01).astype(np.uint16)

# %%
img[ch_name+'50_mask'] = (image_filtered > 0.5).astype(np.uint16)
img[ch_name+'50_clip'] = img[ch_name] * img[ch_name+'50_mask']

# %% [raw]
# # View image to make supervised segmentation
# viewer = napari.Viewer()
# for key in img.keys():
#     viewer.add_image( img[key], name=key )

# %% [markdown]
# ## Segment Dusp

# %%
ch_name = 'dusp'

# %%
image_filtered = mask.gfilter( img[ch_name], sigma )
image_filtered = mask.minmaxnorm( image_filtered )
# Out:
# Relative dynamic range, (max - min)/max = 0.9207676707122809

# %%
for pc in [40, 60, 70, 80]:
    img[ch_name + str(pc) + '_clip'] = img[ch_name] * (image_filtered > pc * 0.01).astype(np.uint16)

# %%
img[ch_name+'50_mask'] = (image_filtered > 0.5).astype(np.uint16)
img[ch_name+'50_clip'] = img[ch_name] * img[ch_name+'50_mask']

# %% [raw]
# # View image to make supervised segmentation
# viewer = napari.Viewer()
# for key in img.keys():
#     viewer.add_image( img[key], name=key )

# %% [markdown]
# # Flip and rotate

# %% [raw]
# img = roi.rotate( img, 0, 0, -90 )

# %%
for key in img.keys():
    img[key] = np.flip( img[key], 1)
for key in img.keys():
    img[key] = np.flip( img[key], 2)

# %% [raw]
# plot.preview(img, 0.5, 1, False, 'none')

# %% [raw]
# # View image to make supervised segmentation
# viewer = napari.Viewer()
# for key in img.keys():
#     viewer.add_image( img[key], name=key)

# %% [markdown]
# # Save preprocessed image

# %%
img_arr = np.array( [img[key] for key in img.keys()] )
img_arr_keys = np.array( [key for key in img.keys()] )

# %%
folder_to_save = r'/home/natalia/Documents/github_image_analysis/experimental_data/treatment_all/'

# %%
file_to_save = f'hcr23_{sample}'
file_to_save
# Out:
# 'hcr23_lb76_fr'

# %%
path_to_save = os.path.join(folder_to_save, file_to_save)

# %%
line_to_add = f'{img_path}   {path_to_save}'

info_file_path = os.path.join(folder_to_save, 'original_file_path_pretreated_file_path.txt')

if not os.path.isfile(info_file_path):
    # Create the file if it doesn't exist
    with open(info_file_path, 'w') as file:
        file.write(line_to_add + '\n')
else:
    # Append the line if the file already exists
    with open(info_file_path, 'a') as file:
        file.write(line_to_add + '\n')

# %%
np.save( path_to_save, img_arr)

# %%
np.save( path_to_save.split('.')[0] + '_keys.npy', img_arr_keys )

# %%
np.save( path_to_save.split('.')[0] + '_pixel.npy', pixel_size )
